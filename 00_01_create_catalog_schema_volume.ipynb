# %%
#Create a calalog for the NYCTaxi Project
spark.sql("create catalog if not exists nyctaxi managed location'abfss://unity-catalog-storage@dbstorage45jfqxl3bfkis.dfs.core.windows.net/7405608950823916'")
# Out:
# DataFrame[]

# %%
#Create a schema for the NYCTaxi Project following the Medillian Architecture
spark.sql("create schema if not exists nyctaxi.00_landing")
spark.sql("create schema if not exists nyctaxi.01_Bronze")
spark.sql("create schema if not exists nyctaxi.02_Silver")
spark.sql("create schema if not exists nyctaxi.03_Gold")
# Out:
# DataFrame[]

# %%
#Create a Volume to save data in the Landing schema
spark.sql("create volume if not exists nyctaxi.00_landing.data_source")
# Out:
# DataFrame[]
